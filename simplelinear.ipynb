# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.7 MB ? eta -:--:--
#    ----- ---------------------------------- 1.8/12.7 MB 6.7 MB/s eta 0:00:02
#    -------------- ------------------------- 4.5/12.7 MB 9.3 MB/s eta 0:00:01
#    ------------------- -------------------- 6.3/12.7 MB 9.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.9/12.7 MB 9.9 MB/s eta 0:00:01
#    ------------------------------------ --- 11.5/12.7 MB 10.8 MB/s eta 0:00:01
#    ---------------------------------------- 12.7/12.7 MB 10.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# ...

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/11.0 MB 4.2 MB/s eta 0:00:03
#    -------------- ------------------------- 3.9/11.0 MB 9.0 MB/s eta 0:00:01
#    --------------------------- ------------ 7.6/11.0 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 12.7 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 11.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\dipak\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#    - -------------------------------------- 0.5/10.7 MB 3.4 MB/s eta 0:00:04
#    -------- ------------------------------- 2.4/10.7 MB 6.7 MB/s eta 0:00:02
#    -------------------- ------------------- 5.5/10.7 MB 10.2 MB/s eta 0:00:01
#    -------------------------------- ------- 8.7/10.7 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 10.7/10.7 MB 11.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/41.0 MB ? eta -:--:--
#    --- ------------------------------------ 3.1/41.0 MB 16.8 MB/s eta 0:00:03
#    ----- ---------------------------------- 5.2/41.0 MB 13.3 MB/s eta 0:00:03
#    -------- ------------------------------- 8.9/41.0 MB 14.6 MB/s eta 0:00:03
#    ----------- ---------------------------- 11.8/41.0 MB 14.5 MB/s eta 0:00:03
# ...

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 3.4 MB/s eta 0:00:03
#    ------------ --------------------------- 2.6/8.1 MB 8.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.1 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 11.6 MB/s eta 0:00:00
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 14.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 2.7/2.7 MB 15.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
import numpy as np 
import matplotlib as plt
import pandas as pd

# %%
url= "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML0101EN-SkillsNetwork/labs/Module%202/data/FuelConsumptionCo2.csv"

# %%
df = pd.read_csv(url)

# %%
# Verify the successful load with some random selected data 
df.sample(5)
# Out:
#       MODELYEAR       MAKE        MODEL             VEHICLECLASS  ENGINESIZE  \
# 462        2014        GMC   SIERRA 4WD  PICKUP TRUCK - STANDARD         6.2
# 79         2014        BMW  328d xDRIVE                  COMPACT         2.0
# 1060       2014      VOLVO      S80 AWD                 MID-SIZE         3.0
# 660        2014      LEXUS      GS 450h                 MID-SIZE         3.5
# 273        2014  CHEVROLET     TRAX AWD              SUV - SMALL         1.4
#
#       CYLINDERS TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  \
# 462           8           A6        Z                  16.4
# 79            4           A8        D                   7.6
# 1060          6          AS6        X                  13.2
# 660           6          AV8        Z                   7.7
# 273           4          AS6        X                  10.0
#
#       FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# ...

# %%
# Explore the data
df.describe()
# Out:
#        MODELYEAR   ENGINESIZE    CYLINDERS  FUELCONSUMPTION_CITY  \
# count     1067.0  1067.000000  1067.000000           1067.000000
# mean      2014.0     3.346298     5.794752             13.296532
# std          0.0     1.415895     1.797447              4.101253
# min       2014.0     1.000000     3.000000              4.600000
# 25%       2014.0     2.000000     4.000000             10.250000
# 50%       2014.0     3.400000     6.000000             12.600000
# 75%       2014.0     4.300000     8.000000             15.550000
# max       2014.0     8.400000    12.000000             30.200000
#
#        FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# count          1067.000000           1067.000000               1067.000000
# mean              9.474602             11.580881                 26.441425
# std               2.794510              3.485595                  7.468702
# min               4.900000              4.700000                 11.000000
# ...

# %%
cdf = df[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB','CO2EMISSIONS']]
cdf.sample(9)
# Out:
#       ENGINESIZE  CYLINDERS  FUELCONSUMPTION_COMB  CO2EMISSIONS
# 835          3.7          6                  11.7           269
# 357          2.0          4                   9.6           221
# 949          2.5          4                  11.2           258
# 583          2.4          4                  11.1           255
# 494          1.5          4                   6.3           145
# 945          2.5          4                   8.6           198
# 1059         3.2          6                  10.2           235
# 1060         3.0          6                  11.5           264
# 2            1.5          4                   5.9           136

# %%
viz = cdf[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB','CO2EMISSIONS']]
viz.hist()
plt.pyplot.show()

# %%
plt.pyplot.scatter(cdf.FUELCONSUMPTION_COMB, cdf.CO2EMISSIONS,  color='blue')
plt.pyplot.xlabel("FUELCONSUMPTION_COMB")
plt.pyplot.ylabel("Emission")
plt.pyplot.show()

# %%
plt.pyplot.scatter(cdf.ENGINESIZE, cdf.CO2EMISSIONS,  color='blue')
plt.pyplot.xlabel('Engine size')
plt.pyplot.ylabel('Emission')
plt.pyplot.xlim(0,27)
plt.pyplot.show()

# %%
plt.pyplot.scatter(cdf.CYLINDERS, cdf.CO2EMISSIONS, color='blue')
plt.pyplot.xlabel('Cylinder')
plt.pyplot.ylabel('Emission')
plt.pyplot.show()

# %%
x = cdf.ENGINESIZE.to_numpy()
y = cdf.CO2EMISSIONS.to_numpy()

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
type(X_train)
# Out:
# numpy.ndarray

# %%
np.shape(X_train)
# Out:
# (853,)

# %%
# Build a simple linear regression model

# %%
from sklearn import linear_model

regressor = linear_model.LinearRegression()

regressor.fit(X_train.reshape(-1,1),y_train)
# Out:
# LinearRegression()

# %%
print("Cofficients: ",regressor.coef_[0])
print("Intercept: ", regressor.intercept_)
# Out:
# Cofficients:  38.992978724434074
# Intercept:  126.28970217408721

# %%
# Here cofficeints and intercept are the regression parameters
# which is defined by the model
# They define the slope and intercept of the best-fit line to the training data

# %%
# Model visualization

# %%
plt.pyplot.scatter(X_train,y_train, color='blue')
plt.pyplot.plot(X_train, regressor.coef_*X_train+regressor.intercept_)
plt.pyplot.xlabel("Engine Size")
plt.pyplot.ylabel("Emission")
# Out:
# Text(0, 0.5, 'Emission')

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

y_test_ = regressor.predict(X_test.reshape(-1,1))

# %%
# Evaluation

# %%
print("Mean absolute error: ",mean_absolute_error(y_test,y_test_))
print("Mean squared error: ",mean_squared_error(y_test,y_test_)) 
print("Root Mean squared error: ",np.sqrt(mean_squared_error(y_test,y_test_)))
print("R2-score: ",r2_score(y_test,y_test_))
# Out:
# Mean absolute error:  0.0
# Mean squared error:  0.0
# Root Mean squared error:  0.0
# R2-score:  1.0

# %%
plt.pyplot.scatter(X_test,y_test)
plt.pyplot.plot(X_test, regressor.coef_*X_test+regressor.intercept_)
plt.pyplot.xlabel("Engine size")
plt.pyplot.ylabel("Emission")
# Out:
# Text(0, 0.5, 'Emission')
